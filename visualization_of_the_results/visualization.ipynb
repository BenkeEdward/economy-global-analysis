# %% [markdown]
# ## For the visualization I'll use packages such as seaborn

# %% [markdown]
# ## Import needed packages

# %%
import seaborn
import import_ipynb
from ML_model.ML_model_training import y_pred,y_test
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualization
