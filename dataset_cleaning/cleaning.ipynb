# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
ds_pd = pd.read_csv(r'../dataset_old/Global Economy Indicators.csv')

# %% [markdown]
# ## Cleaning The Dataset

# %%
from pathlib import Path

path = Path(r'../dataset_new/Global Economy Indicators New Cleaned.csv')

ds_pd_new = ds_pd.drop(columns=[' CountryID ',' Population ',' Currency ',' Year ',' Country ',' AMA exchange rate '])
ds_pd_new.replace(to_replace=np.nan,value=0,inplace=True)
ds_pd_new.to_csv(path)

# %%
# Out:
#        IMF based exchange rate   Per capita GNI   \
# 0                      0.044998              164
# 1                      0.044998              168
# 2                      0.044998              149
# 3                      0.044998              150
# 4                      0.044998              177
# ...                         ...              ...
# 10507                  9.519501             1448
# 10508                 10.458143             1451
# 10509                 12.889418             1246
# 10510                 18.344093              928
# 10511                 20.018487             1062
#
#        Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 0                                           8.699174e+08
# 1                                           9.108281e+08
# 2                                           8.279453e+08
# 3                                           8.554869e+08
# 4                                           1.035913e+09
# ...
